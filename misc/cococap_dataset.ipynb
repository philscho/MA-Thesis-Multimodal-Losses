# %%
import torchvision.datasets as dset
import torchvision.transforms as transforms

# %%
cap = dset.CocoCaptions(root = '/home/data/COCOcaptions/train2014',
                        annFile = '/home/data/COCOcaptions/annotations/captions_train2014.json',
                        transform=transforms.PILToTensor())

print('Number of samples: ', len(cap))
# Out:
# loading annotations into memory...
# Done (t=17.53s)
# creating index...
# index created!
# Number of samples:  82783

# %%
img, target = cap[123] # load 4th sample

print("Image Size: ", img.size())
print(target)
# Out:
# Image Size:  torch.Size([3, 480, 640])
# ['Two very big elephants standing together in an enclosure.', 'two elephants standing next to each other on a dirt ground next to trees.', 'Two elephants in a zoo grazing on leaves.', 'People stand by watching a couple elephants taking a nice walk together', 'two elephants on a dirt ground near tres']

# %%
from PIL import Image
import IPython.display as display

# %%
# Convert the tensor to a PIL Image
image_pil = transforms.ToPILImage()(img)

# Display the image using PIL
display.display(image_pil)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
